# %%
import geodatasets
import pandas as pd
import geopandas
import geodatasets
import contextily as cx

import api_test
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#                          facility_name location_type     operator  \
# 3                    Refinery Building          Park  Domino Park
# 6                         Maspeth Park          Park    NYC Parks
# 8           Fort Hamilton Library, BPL       Library          BPL
# 9                    Rienzi Playground          Park    NYC Parks
# 10                    Lopez Playground          Park    NYC Parks
# ...                                ...           ...          ...
# 1061  Nicholas Naquan Heyward Jr. Park          Park    NYC Parks
# 1062           Soundview Library, NYPL       Library         NYPL
# 1063            Haffen Park Playground          Park    NYC Parks
# 1064          Bay Terrace Library, QPL       Library          QPL
# 1065        Richmond Hill Library, QPL       Library          QPL
#
#            status changing_stations   latitude   longitude  \
# 3     Operational               NaN  40.714424  -73.967306
# 6     Operational               Yes  40.730900  -73.925400
# 8     Operational               Yes  40.616381  -74.031371
# 9     Operational                No  40.887640  -73.858800
# 10    Operational               NaN  40.611270  -74.085000
# ...           ...               ...        ...         ...
# 1061  Operational               Yes  40.684690  -73.987800
# 1062  Operational                No  40.818718  -73.862891
# 1063  Operational                No  40.873540  -73.839300
# 1064  Operational               Yes  40.782532  -73.777012
# 1065  Operational               Yes  40.700806  -73.831644
#
#                                              location_1  \
# 3     {'type': 'Point', 'coordinates': [-73.967306, ...
# 6     {'type': 'Point', 'coordinates': [-73.9254, 40...
# 8     {'type': 'Point', 'coordinates': [-74.031371, ...
# 9     {'type': 'Point', 'coordinates': [-73.8588, 40...
# 10    {'type': 'Point', 'coordinates': [-74.085, 40....
# ...                                                 ...
# 1061  {'type': 'Point', 'coordinates': [-73.9878, 40...
# 1062  {'type': 'Point', 'coordinates': [-73.862891, ...
# 1063  {'type': 'Point', 'coordinates': [-73.8393, 40...
# 1064  {'type': 'Point', 'coordinates': [-73.777012, ...
# 1065  {'type': 'Point', 'coordinates': [-73.831644, ...
#
#      :@computed_region_yeji_bk3q :@computed_region_sbqj_enih  \
# 3                              2                          56
# 6                              3                          66
# 8                              2                          41
# 9                              5                          30
# 10                             1                          74
# ...                          ...                         ...
# 1061                           2                          48
# 1062                           5                          26
# 1063                           5                          30
# 1064                           3                          67
# 1065                           3                          60
#
#      :@computed_region_92fq_4b7q :@computed_region_f5dn_yrer  \
# 3                             38                          36
# 6                             34                          53
# 8                             44                          10
# 9                              2                          29
# 10                            13                           4
# ...                          ...                         ...
# 1061                          38                          14
# 1062                          31                          58
# 1063                           2                          29
# 1064                          20                          22
# 1065                          28                          46
#
#              accessibility                        restroom_type        open  \
# 3                      NaN                                  NaN  Year Round
# 6                      NaN                                  NaN  Year Round
# 8         Fully Accessible  Single-Stall All Gender Restroom(s)  Year Round
# 9         Fully Accessible            Multi-Stall W/M Restrooms  Year Round
# 10        Fully Accessible            Multi-Stall W/M Restrooms  Year Round
# ...                    ...                                  ...         ...
# 1061        Not Accessible            Multi-Stall W/M Restrooms  Year Round
# 1062  Partially Accessible  Single-Stall All Gender Restroom(s)  Year Round
# 1063      Fully Accessible            Multi-Stall W/M Restrooms  Year Round
# 1064      Fully Accessible  Single-Stall All Gender Restroom(s)  Year Round
# 1065                   NaN  Single-Stall All Gender Restroom(s)  Year Round
#
#                                      hours_of_operation  \
# 3                                              6am-11pm
# 6                        8am-4pm, Open later seasonally
# 8     Monday\t10 am - 6 pm\nTuesday\t1 pm - 8 pm\nWe...
# 9                        8am-4pm, Open later seasonally
# 10                       8am-4pm, Open later seasonally
# ...                                                 ...
# 1061                     8am-4pm, Open later seasonally
# 1062  Sunday: Closed \nMonday: 10:00 am - 6:00 pm \n...
# 1063                     8am-4pm, Open later seasonally
# 1064  Sunday: Closed\nMonday: 10:00 am - 6:00 pm\nTu...
# 1065  Sunday: Closed \nMonday: 10:00 am - 6:00 pm \n...
#
#                                                 website  \
# 3                                                   NaN
# 6                                                   NaN
# 8     {'url': 'https://www.bklynlibrary.org/location...
# 9                                                   NaN
# 10                                                  NaN
# ...                                                 ...
# 1061                                                NaN
# 1062  {'url': 'https://www.nypl.org/locations/soundv...
# 1063                                                NaN
# 1064  {'url': 'https://www.queenslibrary.org/about-u...
# 1065  {'url': 'https://www.queenslibrary.org/about-u...
#
#                                        additional_notes
# 3                                                   NaN
# 6                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# ...                                                 ...
# 1061                                                NaN
# 1062                                                NaN
# 1063                                                NaN
# 1064  Each restroom is accessible by key.  They are ...
# 1065                      Yes, a key is needed to enter
#
# [975 rows x 18 columns]

# %%
nyc_df = geopandas.read_file(geodatasets.get_path("nybb"))
ax = nyc_df.plot(figsize=(10, 10), alpha=0.5, edgecolor="k")
nyc_df
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...
