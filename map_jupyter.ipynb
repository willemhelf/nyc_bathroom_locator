# %%
import geodatasets
import pandas as pd
import geopandas
import numpy as np
import geodatasets
import contextily as cx
from cartopy import crs as ccrs
from cartopy import feature as cfeature
import matplotlib.pyplot as plt
import geoplot
from geodatasets import get_path

import api_test

# %%
main_frame = api_test.operational

br_map = geopandas.GeoDataFrame(
    main_frame, geometry=geopandas.points_from_xy(main_frame["longitude"], main_frame["latitude"], crs=4326)
)

br_map.head()
# Out:
#                  facility_name location_type     operator       status  \
# 3            Refinery Building          Park  Domino Park  Operational
# 6                 Maspeth Park          Park    NYC Parks  Operational
# 8   Fort Hamilton Library, BPL       Library          BPL  Operational
# 9            Rienzi Playground          Park    NYC Parks  Operational
# 10            Lopez Playground          Park    NYC Parks  Operational
#
#    changing_stations   latitude   longitude  \
# 3                NaN  40.714424  -73.967306
# 6                Yes  40.730900  -73.925400
# 8                Yes  40.616381  -74.031371
# 9                 No  40.887640  -73.858800
# 10               NaN  40.611270  -74.085000
#
#                                            location_1  \
# 3   {'type': 'Point', 'coordinates': [-73.967306, ...
# 6   {'type': 'Point', 'coordinates': [-73.9254, 40...
# 8   {'type': 'Point', 'coordinates': [-74.031371, ...
# ...

# %%
geo_df=geopandas.GeoDataFrame(main_frame,geometry=geopandas.points_from_xy(main_frame["longitude"], main_frame["latitude"]))

# %%
df = geopandas.read_file(geodatasets.get_path("nybb"))
df_wm = df.to_crs(epsg=4326)
ax = df_wm.plot(figsize=(10, 10), alpha=0.5, edgecolor="k")
geo_df.plot(ax=ax, color="red")
# Out:
# <Axes: >

# %%
br_map.explore(tooltip=['facility_name', 'hours_of_operation', 'open'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
